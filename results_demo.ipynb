# %%
from stat_utils import *
from model_food101 import get_data_loaders
import matplotlib.pyplot as plt
import numpy as np
import torch

# %% [raw]
# First, graphs of test and train accuracy and train accuracy , for cifar10.

# %%
zero_noise_csv = "stats/epoch_stats_cifar10_2023-05-11_old.csv"
small_noise_csv = "stats/epoch_stats_cifar10_2023-05-11_noise_10.0.csv"
large_noise_csv = "stats/epoch_stats_cifar10_2023-05-11_noise_20.0.csv"
plot_errors(zero_noise_csv, small_noise_csv, large_noise_csv, "cifar10")

# %% [raw]
# Now, graphs of test and train accuracy and train accuracy , for food101.

# %%
zero_noise_csv = "stats/epoch_stats_2023-05-04.csv"
small_noise_csv = "stats/epoch_stats_food101_2023-05-19_noise_10.0.csv"
large_noise_csv = "stats/epoch_stats_food101_2023-05-12_noise_20.0.csv"
plot_errors(zero_noise_csv, small_noise_csv, large_noise_csv, "food101")
